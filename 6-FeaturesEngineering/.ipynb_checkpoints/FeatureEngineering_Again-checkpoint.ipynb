# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_titanic=sns.load_dataset("titanic")

# %%
df_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#Filling to age

# %%
sns.boxplot(data=df_titanic,y="age")
# Out:
# <Axes: ylabel='age'>

# %%
df_titanic_FAge=df_titanic.copy()

# %%
df_titanic_FAge["age"]=df_titanic_FAge["age"].fillna(df_titanic_FAge["age"].median())

# %%
df_titanic_FAge
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_titanic_FAge.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df_titanic_FAge["Age"]=df_titanic["age"].fillna(df_titanic["age"].mean())

# %%
df_titanic_FAge
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df_titanic_FAge[["age","Age"]]
# Out:
#       age        Age
# 0    22.0  22.000000
# 1    38.0  38.000000
# 2    26.0  26.000000
# 3    35.0  35.000000
# 4    35.0  35.000000
# ..    ...        ...
# 886  27.0  27.000000
# 887  19.0  19.000000
# 888  28.0  29.699118
# 889  26.0  26.000000
# 890  32.0  32.000000
#
# [891 rows x 2 columns]

# %%
#mode imputation -->categorical

# %%
df_titanic[df_titanic["embarked"].isnull()]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone
# 61   woman       False    B         NaN   yes   True
# 829  woman       False    B         NaN   yes   True

# %%
df_titanic["embarked"].value_counts()
# Out:
# embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df_titanic["Embarked_new"]=df_titanic["embarked"].fillna(df_titanic["embarked"].mode()[0])

# %%
df_titanic["embarked"].mode()
# Out:
# 0    S
# Name: embarked, dtype: object

# %%
df_titanic.isnull().sum()
# Out:
# survived          0
# pclass            0
# sex               0
# age             177
# sibsp             0
# parch             0
# fare              0
# embarked          2
# class             0
# who               0
# adult_male        0
# deck            688
# embark_town       2
# alive             0
# alone             0
# Embarked_new      0
# dtype: int64

# %%
df_titanic.drop("embarked",axis=1)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare   class    who  \
# 0           0       3    male  22.0      1      0   7.2500   Third    man
# 1           1       1  female  38.0      1      0  71.2833   First  woman
# 2           1       3  female  26.0      0      0   7.9250   Third  woman
# 3           1       1  female  35.0      1      0  53.1000   First  woman
# 4           0       3    male  35.0      0      0   8.0500   Third    man
# ..        ...     ...     ...   ...    ...    ...      ...     ...    ...
# 886         0       2    male  27.0      0      0  13.0000  Second    man
# 887         1       1  female  19.0      0      0  30.0000   First  woman
# 888         0       3  female   NaN      1      2  23.4500   Third  woman
# 889         1       1    male  26.0      0      0  30.0000   First    man
# 890         0       3    male  32.0      0      0   7.7500   Third    man
#
#      adult_male deck  embark_town alive  alone Embarked_new
# ...

# %%
df_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df_titanic.isnull().sum()
# Out:
# survived          0
# pclass            0
# sex               0
# age             177
# sibsp             0
# parch             0
# fare              0
# embarked          2
# class             0
# who               0
# adult_male        0
# deck            688
# embark_town       2
# alive             0
# alone             0
# Embarked_new      0
# dtype: int64

# %%
#BALANCING DATA

# %%
np.random.seed(42)

# %%
df_titanic["deck"].value_counts()
# Out:
# deck
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# Name: count, dtype: int64

# %%
#upsampling

# %%
from sklearn.utils import resample

# %%
non_mising=df_titanic["deck"].dropna()

# %%
fillvalues=resample(non_mising,replace=True,n_samples=df_titanic["deck"].isna().sum(),random_state=42).reset_index(drop=True)

# %%
df_titanic["Deck"]=df_titanic["deck"].copy()

# %%
df_titanic.loc[df_titanic["Deck"].isna(),"Deck"]=fillvalues.values

# %%
#Upsample Paris

# %%
df_weather=pd.read_excel("6-weatherna.xlsx")

# %%
df_weather
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0      20.0      10.0       15.0   12.0
# 1      21.0      10.0        NaN   14.0
# 2       NaN      13.0       18.0   15.0
# 3      22.0      14.0       19.0   18.0
# 4      25.0      15.0       15.0   20.0
# 5      28.0       NaN       22.0    NaN
# 6      15.0      12.0       15.0   15.0
# 7      20.0      15.0       14.0    NaN
# 8      22.0      16.0       16.0    NaN

# %%
#upsamling

# %%
non_paris=df_weather["Paris"].dropna()

# %%
non_paris
# Out:
# 0    12.0
# 1    14.0
# 2    15.0
# 3    18.0
# 4    20.0
# 6    15.0
# Name: Paris, dtype: float64

# %%
fill_paris=resample(non_paris,replace=True,n_samples=df_weather["Paris"].isna().sum(),random_state=42).reset_index(drop=True)

# %%
fill_paris
# Out:
# 0    18.0
# 1    20.0
# 2    15.0
# Name: Paris, dtype: float64

# %%
df_weather["PARIS_NEW"]=resample(non_paris,replace=True,n_samples=len(df_weather),random_state=42).reset_index(drop=True)

# %%
df_weather["PARIS_NEW"]
# Out:
# 0    18.0
# 1    20.0
# 2    15.0
# 3    20.0
# 4    20.0
# 5    14.0
# 6    15.0
# 7    15.0
# 8    15.0
# Name: PARIS_NEW, dtype: float64

# %%
df_weather
# Out:
#    Istanbul  New York  Amsterdam  Paris  PARIS_NEW
# 0      20.0      10.0       15.0   12.0       18.0
# 1      21.0      10.0        NaN   14.0       20.0
# 2       NaN      13.0       18.0   15.0       15.0
# 3      22.0      14.0       19.0   18.0       20.0
# 4      25.0      15.0       15.0   20.0       20.0
# 5      28.0       NaN       22.0    NaN       14.0
# 6      15.0      12.0       15.0   15.0       15.0
# 7      20.0      15.0       14.0    NaN       15.0
# 8      22.0      16.0       16.0    NaN       15.0

# %%
df_weather["PARIS_NEW_NOT_RANDOM"]=df_weather["Paris"].copy()

# %%
df_weather["PARIS_NEW_NOT_RANDOM"]
# Out:
# 0    12.0
# 1    14.0
# 2    15.0
# 3    18.0
# 4    20.0
# 5     NaN
# 6    15.0
# 7     NaN
# 8     NaN
# Name: PARIS_NEW_NOT_RANDOM, dtype: float64

# %%
df_weather.loc[df_weather["PARIS_NEW_NOT_RANDOM"].isna(),"PARIS_NEW_NOT_RANDOM"]=fill_paris.values

# %%
df_weather
# Out:
#    Istanbul  New York  Amsterdam  Paris  PARIS_NEW  PARIS_NEW_NOT_RANDOM
# 0      20.0      10.0       15.0   12.0       18.0                  12.0
# 1      21.0      10.0        NaN   14.0       20.0                  14.0
# 2       NaN      13.0       18.0   15.0       15.0                  15.0
# 3      22.0      14.0       19.0   18.0       20.0                  18.0
# 4      25.0      15.0       15.0   20.0       20.0                  20.0
# 5      28.0       NaN       22.0    NaN       14.0                  18.0
# 6      15.0      12.0       15.0   15.0       15.0                  15.0
# 7      20.0      15.0       14.0    NaN       15.0                  20.0
# 8      22.0      16.0       16.0    NaN       15.0                  15.0

# %%
#SMOTE

# %%
set1no=900
set2no=100

# %%
df1=pd.DataFrame({
    "feature_1":np.random.normal(loc=0,scale=1,size=set1no),
    "feature_2":np.random.normal(loc=0,scale=1,size=set1no),
    "target":[0]*set1no
})
df2=pd.DataFrame({
    "feature_1":np.random.normal(loc=0,scale=1,size=set2no),
    "feature_2":np.random.normal(loc=0,scale=1,size=set2no),
    "target":[1]*set2no 
})

# %%
df1
# Out:
#      feature_1  feature_2  target
# 0    -0.675178  -0.045512       0
# 1    -0.144519  -0.424236       0
# 2    -0.792420  -0.569833       0
# 3    -0.307962   0.329509       0
# 4    -1.893615  -1.517174       0
# ..         ...        ...     ...
# 895   3.926238  -0.325611       0
# 896  -2.084113  -0.164335       0
# 897   1.724697   0.212093       0
# 898  -0.287448  -0.993359       0
# 899   0.287329  -1.015879       0
#
# [900 rows x 3 columns]

# %%
df2
# Out:
#     feature_1  feature_2  target
# 0   -1.388543  -0.556119       1
# 1   -1.600271  -0.130060       1
# 2   -1.217283   1.669070       1
# 3    0.159463  -0.942558       1
# 4   -0.892788   1.614779       1
# ..        ...        ...     ...
# 95   1.001632   0.028458       1
# 96   1.393455  -2.077812       1
# 97   0.710549  -0.320298       1
# 98   0.429341   1.643378       1
# 99   0.379640   0.360648       1
#
# [100 rows x 3 columns]

# %%
df=pd.concat([df1,df2])

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample=SMOTE()

# %%
(X,y)=oversample.fit_resample(df[["feature_1","feature_2"]],df["target"])

# %%
X
# Out:
#       feature_1  feature_2
# 0     -0.675178  -0.045512
# 1     -0.144519  -0.424236
# 2     -0.792420  -0.569833
# 3     -0.307962   0.329509
# 4     -1.893615  -1.517174
# ...         ...        ...
# 1795  -0.319929  -0.746879
# 1796   0.794455   0.849616
# 1797   0.225699   1.529741
# 1798   0.161328   1.764309
# 1799  -0.283191  -0.838463
#
# [1800 rows x 2 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1795    1
# 1796    1
# 1797    1
# 1798    1
# 1799    1
# Name: target, Length: 1800, dtype: int64

# %%
df_X_y=pd.concat([X,y],axis=1)

# %%
df_X_y
# Out:
#       feature_1  feature_2  target
# 0     -0.675178  -0.045512       0
# 1     -0.144519  -0.424236       0
# 2     -0.792420  -0.569833       0
# 3     -0.307962   0.329509       0
# 4     -1.893615  -1.517174       0
# ...         ...        ...     ...
# 1795  -0.319929  -0.746879       1
# 1796   0.794455   0.849616       1
# 1797   0.225699   1.529741       1
# 1798   0.161328   1.764309       1
# 1799  -0.283191  -0.838463       1
#
# [1800 rows x 3 columns]

# %%
df["target"]=resample(df
# Out:
#   Cell In[127], line 1
#     df["target"]=resample(df
#                             ^
# _IncompleteInputError: incomplete input

# %%
plt.subplot(1,2,1)
plt.scatter(x="feature_1",y="feature_2",data=df,c="target")
plt.subplot(1,2,2)
plt.scatter(x="feature_1",y="feature_2",data=df_X_y,c="target")
