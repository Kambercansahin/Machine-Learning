# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Random seed

# %%
np.random.seed(42)

# %%
set1no=900
set2no=100

# %%
df1=pd.DataFrame({
    "feature_1":np.random.normal(loc=0,scale=1,size=set1no),
    "feature_2":np.random.normal(loc=0,scale=1,size=set1no),
    "target":[0]*set1no})
df2=pd.DataFrame({
    "feature_1":np.random.normal(loc=0,scale=1,size=set2no),
    "feature_2":np.random.normal(loc=0,scale=1,size=set2no),
    "target":[1]*set2no})

# %%
df1
# Out:
#      feature_1  feature_2  target
# 0    -0.619236   0.881072       0
# 1     0.313119   1.556001       0
# 2     1.539607   1.912409       0
# 3    -0.696152   0.864154       0
# 4     0.961854   0.278619       0
# ..         ...        ...     ...
# 895   0.693325   0.339054       0
# 896  -0.428345   1.314152       0
# 897  -2.046935  -0.441605       0
# 898   0.131190  -0.622128       0
# 899   0.086429  -0.553688       0
#
# [900 rows x 3 columns]

# %%
df2
# Out:
#     feature_1  feature_2  target
# 0    0.901551  -0.158742       1
# 1    1.060148  -0.617135       1
# 2    0.033725  -1.030156       1
# 3    1.883082   2.400745       1
# 4    0.031967  -0.388745       1
# ..        ...        ...     ...
# 95   1.312903  -0.443858       1
# 96   0.560015  -0.597760       1
# 97  -2.019019   0.169000       1
# 98  -0.369531   1.181359       1
# 99  -0.041608  -1.199377       1
#
# [100 rows x 3 columns]

# %%
df=pd.concat([df1,df2],ignore_index=True)

# %%
df
# Out:
#      feature_1  feature_2  target
# 0    -0.619236   0.881072       0
# 1     0.313119   1.556001       0
# 2     1.539607   1.912409       0
# 3    -0.696152   0.864154       0
# 4     0.961854   0.278619       0
# ..         ...        ...     ...
# 995   1.312903  -0.443858       1
# 996   0.560015  -0.597760       1
# 997  -2.019019   0.169000       1
# 998  -0.369531   1.181359       1
# 999  -0.041608  -1.199377       1
#
# [1000 rows x 3 columns]

# %%
df["target"].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
#upsamling -->azınlıkları çoğaltmak

# %%
df_minority=df[df["target"]==1]

# %%
df_minority
# Out:
#      feature_1  feature_2  target
# 900   0.901551  -0.158742       1
# 901   1.060148  -0.617135       1
# 902   0.033725  -1.030156       1
# 903   1.883082   2.400745       1
# 904   0.031967  -0.388745       1
# ..         ...        ...     ...
# 995   1.312903  -0.443858       1
# 996   0.560015  -0.597760       1
# 997  -2.019019   0.169000       1
# 998  -0.369531   1.181359       1
# 999  -0.041608  -1.199377       1
#
# [100 rows x 3 columns]

# %%
df_majority=df[df["target"]==0]

# %%
from sklearn.utils import resample

# %%
df_minority_resample=resample(df_minority,replace=True,n_samples=len(df_majority),random_state=42)

# %%
df_minority_resample
# Out:
#      feature_1  feature_2  target
# 951  -1.407042   0.683191       1
# 992   0.865558   0.153549       1
# 914   0.719351  -2.364902       1
# 971  -1.611467   0.889172       1
# 960   0.173305   0.898140       1
# ..         ...        ...     ...
# 952   0.214808   0.155300       1
# 965  -1.553834  -0.176355       1
# 976  -0.622653  -1.586102       1
# 942  -0.382817   0.242347       1
# 974   2.677977  -0.153488       1
#
# [900 rows x 3 columns]

# %%
df_upsamled=pd.concat([df_minority_resample,df_majority])

# %%
df_upsamled
# Out:
#      feature_1  feature_2  target
# 951  -1.407042   0.683191       1
# 992   0.865558   0.153549       1
# 914   0.719351  -2.364902       1
# 971  -1.611467   0.889172       1
# 960   0.173305   0.898140       1
# ..         ...        ...     ...
# 895   0.693325   0.339054       0
# 896  -0.428345   1.314152       0
# 897  -2.046935  -0.441605       0
# 898   0.131190  -0.622128       0
# 899   0.086429  -0.553688       0
#
# [1800 rows x 3 columns]

# %%
df_upsamled["target"].value_counts()
# Out:
# target
# 1    900
# 0    900
# Name: count, dtype: int64

# %%
#down sample

# %%
df_majority
# Out:
#      feature_1  feature_2  target
# 0    -0.619236   0.881072       0
# 1     0.313119   1.556001       0
# 2     1.539607   1.912409       0
# 3    -0.696152   0.864154       0
# 4     0.961854   0.278619       0
# ..         ...        ...     ...
# 895   0.693325   0.339054       0
# 896  -0.428345   1.314152       0
# 897  -2.046935  -0.441605       0
# 898   0.131190  -0.622128       0
# 899   0.086429  -0.553688       0
#
# [900 rows x 3 columns]

# %%
df_majority_downSample=resample(df_majority,replace=True,n_samples=len(df_minority),random_state=42)

# %%
df_majority_downSample
# Out:
#      feature_1  feature_2  target
# 102   2.467204   0.434831       0
# 435   1.459107   0.411182       0
# 860   1.493938  -0.293738       0
# 270   1.058504  -0.989614       0
# 106   0.229872  -1.567329       0
# ..         ...        ...     ...
# 201  -0.818997  -0.365537       0
# 269   0.744584   1.274388       0
# 862   1.349325  -0.898767       0
# 815  -1.383454  -0.945253       0
# 270   1.058504  -0.989614       0
#
# [100 rows x 3 columns]

# %%
df_downsample=pd.concat([df_minority,df_majority_downSample])

# %%
df_downsample
# Out:
#      feature_1  feature_2  target
# 900   0.901551  -0.158742       1
# 901   1.060148  -0.617135       1
# 902   0.033725  -1.030156       1
# 903   1.883082   2.400745       1
# 904   0.031967  -0.388745       1
# ..         ...        ...     ...
# 201  -0.818997  -0.365537       0
# 269   0.744584   1.274388       0
# 862   1.349325  -0.898767       0
# 815  -1.383454  -0.945253       0
# 270   1.058504  -0.989614       0
#
# [200 rows x 3 columns]

# %%
plt.scatter(x=df["feature_1"],y=df["feature_2"],c=df["target"],label="xyz")

# %%
plt.scatter(x=df_upsamled["feature_1"],y=df_upsamled["feature_2"],c=df_upsamled["target"])

# %%
#SMOTE

# %%
plt.scatter(df["feature_1"],df["feature_2"],c=df["target"])

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample=SMOTE()

# %%
(X,y)=oversample.fit_resample(df[["feature_1","feature_2"]],df["target"])

# %%
X
# Out:
#       feature_1  feature_2
# 0     -0.619236   0.881072
# 1      0.313119   1.556001
# 2      1.539607   1.912409
# 3     -0.696152   0.864154
# 4      0.961854   0.278619
# ...         ...        ...
# 1795   0.402683   1.030076
# 1796  -1.026352   1.215925
# 1797  -0.606987   0.228323
# 1798   0.875262   0.057656
# 1799  -0.920442   1.295562
#
# [1800 rows x 2 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1795    1
# 1796    1
# 1797    1
# 1798    1
# 1799    1
# Name: target, Length: 1800, dtype: int64

# %%
oversample_df=pd.concat([X,y],axis=1)

# %%
oversample_df
# Out:
#       feature_1  feature_2  target
# 0     -0.619236   0.881072       0
# 1      0.313119   1.556001       0
# 2      1.539607   1.912409       0
# 3     -0.696152   0.864154       0
# 4      0.961854   0.278619       0
# ...         ...        ...     ...
# 1795   0.402683   1.030076       1
# 1796  -1.026352   1.215925       1
# 1797  -0.606987   0.228323       1
# 1798   0.875262   0.057656       1
# 1799  -0.920442   1.295562       1
#
# [1800 rows x 3 columns]

# %%
plt.scatter(oversample_df["feature_1"],oversample_df["feature_2"],c=oversample_df["target"])
