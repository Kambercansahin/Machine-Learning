# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("1-studyhours.csv")

# %%
df.head()
# Out:
#    Study Hours  Exam Score
# 0          3.9        40.0
# 1          9.6        57.1
# 2          4.5        42.7
# 3         11.4        65.1
# 4         14.4        78.7

# %%
plt.scatter(x="Study Hours",y="Exam Score",data=df)

# %%
X=df[["Study Hours"]]
y=df["Exam Score"]

# %%
X
# Out:
#     Study Hours
# 0           3.9
# 1           9.6
# 2           4.5
# 3          11.4
# 4          14.4
# 5          18.0
# 6          19.2
# 7          22.2
# 8          25.2
# 9          17.4
# 10         21.3
# 11         26.1
# 12         30.0
# 13         27.3
# 14         21.0
# 15         17.7
# 16          5.7
# 17         12.9
# 18         17.4
# 19         21.3
# 20          3.9
# 21          8.1
# 22         14.4
# 23          3.0
# 24          9.6
# 25          5.1
# 26          9.6
# 27         15.6
# 28         17.7
# 29         19.5
# 30         23.4
# 31         25.2
# 32         18.9

# %%
#Test-Train Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=15)

# %%
X_test
# Out:
#     Study Hours
# 25          5.1
# 14         21.0
# 30         23.4
# 16          5.7
# 24          9.6
# 20          3.9
# 19         21.3

# %%
X_train
# Out:
#     Study Hours
# 18         17.4
# 1           9.6
# 2           4.5
# 32         18.9
# 6          19.2
# 3          11.4
# 29         19.5
# 26          9.6
# 9          17.4
# 4          14.4
# 28         17.7
# 10         21.3
# 27         15.6
# 13         27.3
# 17         12.9
# 15         17.7
# 22         14.4
# 31         25.2
# 11         26.1
# 7          22.2
# 0           3.9
# 23          3.0
# 5          18.0
# 12         30.0
# 21          8.1
# 8          25.2

# %%
#STANDARDIZATION

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaller=StandardScaler()

# %%
X_train=scaller.fit_transform(X_train)
X_test=scaller.transform(X_test)

# %%
#AGAIN

# %%
df_again=pd.read_csv("1-studyhours.csv")

# %%
df.head()
# Out:
#    Study Hours  Exam Score
# 0          3.9        40.0
# 1          9.6        57.1
# 2          4.5        42.7
# 3         11.4        65.1
# 4         14.4        78.7

# %%
#Independent(X) and dependent(y)

# %%
X=df_again[["Study Hours"]]
y=df_again["Exam Score"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=15)

# %%
X_train
# Out:
#     Study Hours
# 18         17.4
# 1           9.6
# 2           4.5
# 32         18.9
# 6          19.2
# 3          11.4
# 29         19.5
# 26          9.6
# 9          17.4
# 4          14.4
# 28         17.7
# 10         21.3
# 27         15.6
# 13         27.3
# 17         12.9
# 15         17.7
# 22         14.4
# 31         25.2
# 11         26.1
# 7          22.2
# 0           3.9
# 23          3.0
# 5          18.0
# 12         30.0
# 21          8.1
# 8          25.2

# %%
#Standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.11794385],
#        [-0.97424848],
#        [-1.68837424],
#        [ 0.32798083],
#        [ 0.36998823],
#        [-0.7222041 ],
#        [ 0.41199563],
#        [-0.97424848],
#        [ 0.11794385],
#        [-0.30213013],
#        [ 0.15995124],
#        [ 0.66404001],
#        [-0.13410054],
#        [ 1.50418796],
#        [-0.51216711],
#        [ 0.15995124],
#        [-0.30213013],
#        [ 1.21013618],
#        [ 1.33615837],
#        [ 0.7900622 ],
#        [-1.77238903],
#        [-1.89841122],
#        [ 0.20195864],
#        [ 1.88225453],
#        [-1.18428547],
#        [ 1.21013618]])

# %%
X_test
# Out:
# array([[-1.60435944],
#        [ 0.62203261],
#        [ 0.95809179],
#        [-1.52034465],
#        [-0.97424848],
#        [-1.77238903],
#        [ 0.66404001]])

# %%
X_test
# Out:
# array([[-1.60435944],
#        [ 0.62203261],
#        [ 0.95809179],
#        [-1.52034465],
#        [-0.97424848],
#        [-1.77238903],
#        [ 0.66404001]])

# %%
#Traning Model Simple linear (basit doğrusal)

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print("Coefficent",regression.coef_)
print("Intercept",regression.intercept_)
# Out:
# Coefficent [16.17860223]
# Intercept 76.9076923076923

# %%
# y = 76 + 16x

# %%
plt.scatter(x=X_train,y=y_train)
plt.plot(X_train,regression.predict(X_train),"r")

# %%
regression.predict(scaler.transform([[20]]))
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([84.70590731])

# %%
#MSE,MAE,RMSE,R2

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred_test=regression.predict(X_test)

# %%
mse=mean_squared_error(y_test,y_pred_test)
msa=mean_absolute_error(y_test,y_pred_test)
rmse=np.sqrt(mean_squared_error(y_test,y_pred_test))
print("mse: ",mse)
print("mas: ",msa)
print("rmse: ",rmse)
# Out:
# mse:  29.45839048833392
# mas:  4.054868128856142
# rmse:  5.427558427906043

# %%
r2=r2_score(y_test,y_pred_test)
print("r2 score:",r2)
# Out:
# r2 score: 0.9196596206825491

# %%
r2_ajusted=1-(1-r2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)

# %%
r2_ajusted
# Out:
# 0.903591544819059

# %%
#AGAIN

# %%
df_again2=pd.read_csv("1-studyhours.csv")

# %%
df_again2.head()
# Out:
#    Study Hours  Exam Score
# 0          3.9        40.0
# 1          9.6        57.1
# 2          4.5        42.7
# 3         11.4        65.1
# 4         14.4        78.7

# %%
#independent and dependent feature

# %%
X=df[["Study Hours"]]
y=df["Exam Score"]

# %%
X.head()
# Out:
#    Study Hours
# 0          3.9
# 1          9.6
# 2          4.5
# 3         11.4
# 4         14.4

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=15)

# %%
X_train.head()
# Out:
#     Study Hours
# 18         17.4
# 1           9.6
# 2           4.5
# 32         18.9
# 6          19.2

# %%
#standartization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-1.60435944],
#        [ 0.62203261],
#        [ 0.95809179],
#        [-1.52034465],
#        [-0.97424848],
#        [-1.77238903],
#        [ 0.66404001]])

# %%
#Linear Regressions

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print("Co",regression.coef_)
print("Int",regression.intercept_)
# Out:
# Co [16.17860223]
# Int 76.9076923076923

# %%
X_train_predict=regression.predict(X_test)

# %%
X_train_predict
# Out:
# array([50.95139904, 86.97131054, 92.40827832, 52.31064098, 61.14571361,
#        48.23291515, 87.65093152])

# %%
regression.predict(scaler.transform([[20]]))
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([84.70590731])

# %%
#Calculate Performance

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mae=mean_absolute_error(y_test,X_train_predict)
mse=mean_squared_error(y_test,X_train_predict)
rmse=np.sqrt(mse)
print("mae: ",mae)
print("mse: ",mse)
print("rmse: ",rmse)
# Out:
# mae:  4.054868128856142
# mse:  29.45839048833392
# rmse:  5.427558427906043

# %%
r2score=r2_score(y_test,X_train_predict)
print("r2 score:",r2score)
# Out:
# r2 score: 0.9196596206825491

# %%
#MultıLinear

# %%
df_multi=pd.read_csv("2-multiplegradesdataset.csv")

# %%
df_multi.head()
# Out:
#    Study Hours  Sleep Hours  Attendance Rate  Social Media Hours  Exam Score
# 0          4.7          7.3             82.9                 3.3        80.7
# 1          3.8          6.6             87.9                 3.3        76.0
# 2          5.0          6.3             88.3                 2.3        89.1
# 3          6.3          7.6             86.0                 3.2        95.9
# 4          3.6          8.0             89.2                 3.3        70.5

# %%
df_multi.corr()
# Out:
#                     Study Hours  Sleep Hours  Attendance Rate  \
# Study Hours            1.000000     0.114015        -0.112860
# Sleep Hours            0.114015     1.000000        -0.222024
# Attendance Rate       -0.112860    -0.222024         1.000000
# Social Media Hours     0.115023    -0.177166         0.068272
# Exam Score             0.804266     0.227694         0.123791
#
#                     Social Media Hours  Exam Score
# Study Hours                   0.115023    0.804266
# Sleep Hours                  -0.177166    0.227694
# Attendance Rate               0.068272    0.123791
# Social Media Hours            1.000000   -0.248743
# Exam Score                   -0.248743    1.000000

# %%
#İndependet and dependent
X=df_multi.iloc[:,:-1]
y=df_multi.iloc[:,-1]

# %%
X
# Out:
#     Study Hours  Sleep Hours  Attendance Rate  Social Media Hours
# 0           4.7          7.3             82.9                 3.3
# 1           3.8          6.6             87.9                 3.3
# 2           5.0          6.3             88.3                 2.3
# 3           6.3          7.6             86.0                 3.2
# 4           3.6          8.0             89.2                 3.3
# 5           3.6          7.9             92.0                 2.3
# 6           6.4          6.2             99.4                 4.9
# 7           5.2          6.7             90.9                 3.5
# 8           3.3          7.3             91.3                 1.8
# 9           4.8          8.0             89.6                 3.7
# 10          3.3          6.5             80.4                 2.0
# 11          3.3          6.8             89.9                 3.8
# 12          4.4          5.9             90.3                 4.2
# ...

# %%
#Train Test

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=15)

# %%
#Standartiziton

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-1.29053937, -0.49984673,  1.62356013,  0.67593203],
#        [-2.16015779,  0.34080459, -0.23742268, -0.17184713],
#        [ 0.36964124,  1.07637448,  1.38343332,  0.88787682],
#        [-1.21148315,  0.13064176, -0.91778199, -0.06587473],
#        [-1.44865181, -0.49984673,  0.90317969, -0.91365388],
#        [-0.26280851, -0.2896839 ,  0.26284151, -1.33754346],
#        [ 1.95076564,  0.65604883, -0.71767631,  0.14607006],
#        [-1.13242693, -0.49984673,  0.56300003,  0.46398724],
#        [-0.57903339, -0.18460248, -1.47807789,  0.56995963],
#        [ 0.36964124,  0.97129307, -0.69766575,  0.46398724],
#        [-1.92298913,  0.86621166, -0.11735928,  0.99384921],
#        [-1.05337071, -0.07952107,  0.04272527,  0.78190442],
#        [ 1.87170942,  0.445886  ,  0.88316912, -1.01962628]])

# %%
#Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test[0]
# Out:
# array([-1.29053937, -0.49984673,  1.62356013,  0.67593203])

# %%
regression.predict(scaler.transform([[5,7,90,2]]))
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([90.88471349])

# %%
#polinomic regression

# %%
df=pd.read_csv("3-customersatisfaction.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Customer Satisfaction  Incentive
# 0           0              -1.282447   1.010513
# 1           1               0.425298   2.281043
# 2           2               1.953070   4.415053
# 3           3               2.625838  10.563600
# 4           4              -1.426333   0.627365

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df.head()
# Out:
#    Customer Satisfaction  Incentive
# 0              -1.282447   1.010513
# 1               0.425298   2.281043
# 2               1.953070   4.415053
# 3               2.625838  10.563600
# 4              -1.426333   0.627365

# %%
X=df[["Customer Satisfaction"]]
y=df["Incentive"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=15)

# %%
X_train.head()
# Out:
#     Customer Satisfaction
# 99               0.512504
# 3                2.625838
# 20              -0.865714
# 55              -1.145369
# 6                2.823460

# %%
y_train.head()
# Out:
# 99     4.356168
# 3     10.563600
# 20     1.460525
# 55     0.702395
# 6      9.011908
# Name: Incentive, dtype: float64

# %%
#Standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
#Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=regression.predict(X_test)

# %%
y_predict
# Out:
# array([ 4.65663741,  3.71913877,  1.64121789,  6.29646523,  3.46766736,
#         5.7580845 ,  4.692485  ,  3.61616231,  5.62448003,  0.13472702,
#         4.47909659,  4.8130839 ,  1.58319087,  0.30515983,  5.27634309,
#         0.41711005, -0.7385295 , -0.32653914,  3.55906887,  1.19798631])

# %%
plt.scatter(df["Customer Satisfaction"],df["Incentive"],color="r")
plt.plot(X_train,regression.predict(X_train),color="b")

# %%
#Control

# %%
from sklearn.metrics import r2_score

# %%
r2Score=r2_score(y_test,y_predict)
print(r2Score)
# Out:
# 0.2705652535622243

# %%
plt.scatter(df["Customer Satisfaction"],df["Incentive"],color="r")
plt.plot(X_train,regression.predict(X_train),color="b")
plt.show()
