# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_eda=pd.read_csv("WineQT.csv")

# %%
df_eda
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df_eda.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
df_eda.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# ...

# %%
df_eda.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
#Alchol and Quality

# %%
#Sulphates and quality

# %%
#density quality

# %%
df_eda.shape
# Out:
# (1143, 13)

# %%
df_eda.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Id                        int64
# dtype: object

# %%
df_eda.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
plt.figure(figsize=(20,6))
sns.boxplot(data=df_eda,x="quality",y="pH")
#Ph arttıkca kalite düşüyor
# Out:
# <Axes: xlabel='quality', ylabel='pH'>

# %%
sns.lineplot(data=df_eda,x="quality",y="pH")
# Out:
# <Axes: xlabel='quality', ylabel='pH'>

# %%
plt.subplot(1,2,1)
sns.countplot(data=df_eda,x="quality")
plt.subplot(1,2,2)
sns.countplot(data=df_eda,x="pH")
# Out:
# <Axes: xlabel='pH', ylabel='count'>

# %%
plt.figure(figsize=(12,5))
sns.heatmap(df_eda.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df_eda.groupby("quality").mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.450000          0.897500     0.211667        2.666667
# 4             7.809091          0.700000     0.165758        2.566667
# 5             8.161077          0.585280     0.240124        2.540476
# 6             8.317749          0.504957     0.263680        2.444805
# 7             8.851049          0.393671     0.386573        2.760140
# 8             8.806250          0.410000     0.432500        2.643750
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.105333             8.166667             24.500000  0.997682
# 4         0.094788            14.848485             40.606061  0.996669
# 5         0.091770            16.612836             55.299172  0.997073
# 6         0.085281            15.215368             39.941558  0.996610
# 7         0.075217            14.538462             37.489510  0.996071
# ...

# %%
df_eda["quality"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='quality'>

# %%
sns.histplot(data=df_eda,x="pH")
# Out:
# <Axes: xlabel='pH', ylabel='Count'>

# %%
sns.histplot(df_eda["pH"])
# Out:
# <Axes: xlabel='pH', ylabel='Count'>

# %%
#Pair-Plot

# %%
sns.pairplot(df_eda)
