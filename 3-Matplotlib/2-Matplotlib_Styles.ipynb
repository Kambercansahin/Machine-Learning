# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data1=np.linspace(0,10,20)

# %%
data2=data1**2

# %%
my_axes1=plt.subplot()
my_axes1.plot(data1,data2)
my_axes1.plot(data2,data1)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 x
#
# NameError: name 'x' is not defined
